# %% [markdown]
# # TrOCR Fine-tuning — Maltese OCR
#
# Before running anything:
# 1. Go to **Runtime → Change runtime type** and select **T4 GPU**
# 2. Upload your data to Google Drive at `MyDrive/maltese-OCR/synthetic/`
#    - `images/` folder (5000 syn_*.jpg files)
#    - `transcriptions.json`
# 3. Upload `train_colab.py` to the Colab file browser (left sidebar)
#
# Then run the cells in order.

# %%
# Cell 1 — Mount Google Drive so the script can read your images
# A pop-up will ask you to sign in and grant access — click through it.
from google.colab import drive
drive.mount('/content/drive')

# Verify your data is visible
import os
images_dir = '/content/drive/MyDrive/maltese-OCR/synthetic/images'
n = len([f for f in os.listdir(images_dir) if f.startswith('syn_')])
print(f'Found {n} synthetic images in Drive')

# %%
# Cell 2 — Install required Python packages
# -q means quiet mode (less output). This takes about 30 seconds.
# !pip install transformers pillow sentencepiece tqdm -q
print('Dependencies installed.')

# %%
# Cell 3 — Confirm a GPU is available
# If this prints False, go to Runtime > Change runtime type and pick T4 GPU.
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('Memory:', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), 'GB')

# %%
# Cell 4 — Run training
# This will take approximately 2-3 hours for 5 epochs on a T4 GPU.
# The best model checkpoint is saved to:
#   MyDrive/maltese-OCR/models/trocr-maltese/
# after every epoch where validation loss improves.
# !python train_colab.py
